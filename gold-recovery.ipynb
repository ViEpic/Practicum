# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их" data-toc-modified-id="Откройте-файлы-и-изучите-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откройте файлы и изучите их</a></span></li><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы" data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы</a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#Проведите-предобработку-данных" data-toc-modified-id="Проведите-предобработку-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведите предобработку данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы" data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной" data-toc-modified-id="Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы" data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# Данные находятся в трёх файлах:
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.

# %% [markdown]
# Описание данных
# Технологический процесс
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# Параметры этапов
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# Наименование признаков
# Наименование признаков имеет такой вид:
#
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
#
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откройте файлы и изучите их

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer
from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
try:
    gold_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date', parse_dates=['date'])
except:
    gold_train = pd.read_csv('D:/Yandex/gold_recovery_train_new.csv', index_col='date', parse_dates=['date'])

# %%
try:
    gold_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date', parse_dates=['date'])
except:
    gold_test = pd.read_csv('D:/Yandex/gold_recovery_test_new.csv', index_col='date', parse_dates=['date'])

# %%
try:
    gold_full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date', parse_dates=['date'])
except:
    gold_full = pd.read_csv('D:/Yandex/gold_recovery_full_new.csv', index_col='date', parse_dates=['date'])

# %%
display(gold_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %%
display(gold_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5290 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5286 non-null   float64
#  1   primary_cleaner.input.depressant            5285 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5286 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
# ...

# %%
display(gold_full.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         19438 non-null  float64
#  1   final.output.concentrate_pb                         19438 non-null  float64
#  2   final.output.concentrate_sol                        19228 non-null  float64
#  3   final.output.concentrate_au                         19439 non-null  float64
#  4   final.output.recovery                               19439 non-null  float64
#  5   final.output.tail_ag                                19438 non-null  float64
#  6   final.output.tail_pb                                19338 non-null  float64
#  7   final.output.tail_sol                               19433 non-null  float64
# ...

# %%
display(gold_train.head())
display(gold_test.head())
display(gold_full.head())
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
display(gold_train.duplicated().sum())
display(gold_test.duplicated().sum())
display(gold_full.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
display(gold_train.isnull().sum())
# Out:
# final.output.concentrate_ag                     1
# final.output.concentrate_pb                     1
# final.output.concentrate_sol                  211
# final.output.concentrate_au                     0
# final.output.recovery                           0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        2
# secondary_cleaner.state.floatbank6_a_level      1
# Length: 86, dtype: int64

# %%
display(gold_test.isnull().sum())
# Out:
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# rougher.input.floatbank10_sulfate              5
# ...

# %%
display(gold_full.isnull().sum())
# Out:
# final.output.concentrate_ag                     1
# final.output.concentrate_pb                     1
# final.output.concentrate_sol                  211
# final.output.concentrate_au                     0
# final.output.recovery                           0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        2
# secondary_cleaner.state.floatbank6_a_level      1
# Length: 86, dtype: int64

# %%
display(gold_train.describe())
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14148.000000                 14148.000000
# mean                      5.142034                    10.132960
# std                       1.369586                     1.654930
# min                       0.000000                     0.000000
# 25%                       4.211620                     9.297355
# 50%                       4.994652                    10.297144
# 75%                       5.859540                    11.170603
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  13938.000000                 14149.000000
# mean                       9.202849                    44.003792
# std                        2.790516                     4.905261
# min                        0.000000                     0.000000
# ...

# %%
display(gold_test.describe())
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5286.000000                       5285.000000
# mean                      174.839652                          8.683596
# std                        43.027080                          3.072050
# min                         2.566156                          0.003839
# 25%                       147.121401                          6.489555
# 50%                       177.828489                          8.052207
# 75%                       208.125438                         10.027764
# max                       265.983123                         40.000000
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5290.000000                     5286.000000
# mean                          7.266339                        1.383803
# std                           0.610219                        0.643474
# ...

# %%
display(gold_full.describe())
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  19228.000000                 19439.000000
# mean                       9.501224                    44.076513
# std                        2.787537                     5.129784
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# - Пропуски в данных занимают незначительное количество
# - Все признаки, кроме столбца date, имеют тип float
# - Явных дубликатов нет
# - Целевые признаки - количественные, для их предсказания ставится задача регрессии

# %% [markdown]
# ### Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле Recovery = ((C * (F - T))/(F * (C - T))) * 100% где:
# - *C* — доля золота в концентрате после флотации/очистки (rougher.output.concentrate_au)
# - *F* — доля золота в сырье/концентрате до флотации/очистки (rougher.input.feed_au)
# - *T* — доля золота в отвальных хвостах после флотации/очистки (rougher.output.tail_au)
#
# Среднее абсолютное отклонение *MAE* для линейной регрессии в общем виде рассчитывается так:
#
# mae = mean_absolute_error(target_valid, predicted_valid)

# %%
# Вычислим эффективность обогащения recovery на обучающей выборке
c = gold_train['rougher.output.concentrate_au']
f = gold_train['rougher.input.feed_au']
t = gold_train['rougher.output.tail_au']
recovery = ((c * (f - t))/(f * (c - t))) * 100
gold_train['rougher_output_recovery_predicted'] = recovery
gold_train.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
# Перед расчётом MAE необходимо заполнить пропуски в данных
gold_train = gold_train.ffill(axis=0)
gold_test = gold_test.ffill(axis=0)
gold_full = gold_full.ffill(axis=0)

# %%
# Найдём MAE между нашими расчётами и значением признака
mae = mean_absolute_error(gold_train['rougher.output.recovery'], gold_train['rougher_output_recovery_predicted'])
display(mae)
# Out:
# 9.73512347450521e-15

# %%
gold_train[['rougher.output.recovery', 'rougher_output_recovery_predicted']].head()
# Out:
#                      rougher.output.recovery  \
# date
# 2016-01-15 00:00:00                87.107763
# 2016-01-15 01:00:00                86.843261
# 2016-01-15 02:00:00                86.842308
# 2016-01-15 03:00:00                87.226430
# 2016-01-15 04:00:00                86.688794
#
#                      rougher_output_recovery_predicted
# date
# 2016-01-15 00:00:00                          87.107763
# 2016-01-15 01:00:00                          86.843261
# 2016-01-15 02:00:00                          86.842308
# 2016-01-15 03:00:00                          87.226430
# 2016-01-15 04:00:00                          86.688794

# %% [markdown]
# Можно сделать вывод, что эффективность обогащения рассчитана правильно.

# %% [markdown]
# ### Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
# Выведем признаки, которые отсутствуют в тестовой выборке
gold_train_columns_remains = set(gold_train.columns) - set(gold_test.columns)
gold_train_remains = gold_train[list(gold_train_columns_remains)]
display(list(gold_train_remains))
# Out:
# ['final.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_pb',
#  'rougher.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'final.output.recovery',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.recovery',
#  'secondary_cleaner.output.tail_au',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'final.output.tail_ag',
#  'primary_cleaner.output.concentrate_sol',
#  'rougher.output.concentrate_pb',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.output.tail_sol',
#  'final.output.concentrate_sol',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
# ...

# %% [markdown]
# Наименование признаков имеет такой вид:
#
# [этап].[тип_параметра].[название_параметра].
#
# Признаки, недоступные в тестовой выборке, имеют следующие типы и параметры:
#
# - output.concentrate - концентрация металлов (золота au, серебра ag, свинца pb) и растворителя/коллоида (sol, solvent aka) в продукте (output) на различных этапах очистки
# - output.tail - отвальные хвосты (tail) продукта (output) на различных этапах очистки
# - calculation - расчётные характеристики
# - rougher.calculation.au_pb_ratio - расчётные характеристики соотношения золота (au) и свинца (pb) в исходном сырье (rougher)
# - rougher.calculation.floatbank10_sulfate_to_au_feed и rougher.calculation.floatbank11_sulfate_to_au_feed - расчётные характеристики подачи (feed) сульфата (sulfate) и золота (au) в исходном сырье (rougher) во флотационной установке (floatbank)
# - rougher.calculation.sulfate_to_au_concentrate - расчётные характеристики концентраций (concentrate) сульфата (sulfate) и золота (au) в исходном сырье (rougher)
#
# Целевые признаки:
#
# - rougher.output.recovery - эффективность обогащения чернового концентрата
# - final.output.recovery - эффективность обогащения финального концентрата
#
# В тестовой выборке нет целевых признаков и отсутствуют некоторые признаки, которые могут быть в обучающей.

# %% [markdown]
# ### Проведите предобработку данных

# %% [markdown]
# Выделим целевые признаки rougher.output.recovery и final.output.recovery из исходных данных gold_recovery_full_new по индексам тестовой выборки gold_recovery_test_new и введём две переменные:
# - features_test - признаки в тестовой выборке gold_recovery_test_new
# - target_test - переменная с целевыми признаками rougher.output.recovery (индекс '0') и final.output.recovery (индекс '1') в тестовой выборке gold_recovery_test_new

# %%
features = gold_test.columns
targets = ['rougher.output.recovery', 'final.output.recovery']
features_test = gold_test[features].reset_index(drop=True)
target_test = gold_full[targets].loc[gold_test.index].reset_index(drop=True)

# %%
# Признаки в тестовой выборке
features_test.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     210.800909                         14.993118
# 1                     215.392455                         14.987471
# 2                     215.259946                         12.884934
# 3                     215.336236                         12.006805
# 4                     199.099327                         10.682530
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                         8.080000                        1.005021
# 1                         8.080000                        0.990469
# 2                         7.786667                        0.996043
# 3                         7.640000                        0.863514
# 4                         7.530000                        0.805575
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1398.981301
# 1                             1398.777912
# ...

# %%
# Целевые признаки в тестовой выборке
target_test.head()
# Out:
#    rougher.output.recovery  final.output.recovery
# 0                89.993421              70.273583
# 1                88.089657              68.910432
# 2                88.412756              68.143213
# 3                87.360133              67.776393
# 4                83.236367              61.467078

# %% [markdown]
# - Изучили данные
# - Эффективность обогащения рассчитана правильно
# - В тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков
# - Провели предобработку данных

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы

# %% [markdown]
# - rougher.input.feed_ - в сырье
# - rougher.output.concentrate_ - в черновом концентрате
# - primary_cleaner.output.concentrate_ - в концентрате после первичной очистки
# - final.output.concentrate_ - в финальном концентрате

# %%
# Список с концентрацией металлов в сырье
rougher_input_feed = ['rougher.input.feed_au','rougher.input.feed_ag','rougher.input.feed_pb','rougher.input.feed_sol']

# %%
# Список с концентрацией металлов в черновом концентрате
rougher_output_concentrate = ['rougher.output.concentrate_au','rougher.output.concentrate_ag',
                              'rougher.output.concentrate_pb','rougher.output.concentrate_sol']

# %%
# Список с концентрацией металлов в концентрате после первичной очистки
primary_cleaner_output_concentrate = ['primary_cleaner.output.concentrate_au','primary_cleaner.output.concentrate_ag',
                                      'primary_cleaner.output.concentrate_pb','primary_cleaner.output.concentrate_sol']

# %%
# Список с концентрацией металлов в финальном концентрате
final_output_concentrate = ['final.output.concentrate_au','final.output.concentrate_ag',
                            'final.output.concentrate_pb','final.output.concentrate_sol']

# %%
# Концентрациям металлов в сырье на разных этапах в обучающей выборке
gold_train_concentrate_metal = gold_train.loc[:, rougher_input_feed + rougher_output_concentrate + 
                                              primary_cleaner_output_concentrate + final_output_concentrate]
gold_train_concentrate_metal.head()
# Out:
#                      rougher.input.feed_au  rougher.input.feed_ag  \
# date
# 2016-01-15 00:00:00               6.486150               6.100378
# 2016-01-15 01:00:00               6.478583               6.161113
# 2016-01-15 02:00:00               6.362222               6.116455
# 2016-01-15 03:00:00               6.118189               6.043309
# 2016-01-15 04:00:00               5.663707               6.060915
#
#                      rougher.input.feed_pb  rougher.input.feed_sol  \
# date
# 2016-01-15 00:00:00               2.284912               36.808594
# 2016-01-15 01:00:00               2.266033               35.753385
# 2016-01-15 02:00:00               2.159622               35.971630
# 2016-01-15 03:00:00               2.037807               36.862241
# 2016-01-15 04:00:00               1.786875               34.347666
#
#                      rougher.output.concentrate_au  \
# date
# 2016-01-15 00:00:00                      19.793808
# ...

# %%
# Максимальные значения концентраций металлов в сырье, в черновом, после первичной очистки и финальном концентратах
metals = ['au', 'ag', 'pb']
stages = ['rougher.input.feed_', 'rougher.output.concentrate_', 
          'primary_cleaner.output.concentrate_', 'final.output.concentrate_']   
for metal in metals:
    max_concentration = 0
    plt.figure(figsize=(15, 5))
    plt.grid(True)
    plt.title('Максимальные значения концентраций металлов в сырье на разных этапах')
    plt.xlabel('Концентрация')
    plt.ylabel('Количество индексаций')
    for stage in stages:
        concentration = gold_train[f'{stage}{metal}']
        plt.hist(concentration, bins=100, alpha=0.7, edgecolor = 'gold')
        plt.legend(['в сырье', 'в черновом концентрате', 'в концентрате после первичной очистки', 'в финальном концентрате'])
        max_concentraition = max(max_concentration, int(concentration.max()))
        print(f'{stage}{metal}:', max_concentraition)
# Out:
# rougher.input.feed_au: 13
# rougher.output.concentrate_au: 28
# primary_cleaner.output.concentrate_au: 45
# final.output.concentrate_au: 52
# rougher.input.feed_ag: 14
# rougher.output.concentrate_ag: 24
# primary_cleaner.output.concentrate_ag: 16
# final.output.concentrate_ag: 16
# rougher.input.feed_pb: 7
# rougher.output.concentrate_pb: 13
# primary_cleaner.output.concentrate_pb: 17
# final.output.concentrate_pb: 17

# %% [markdown]
# Концентрация золота (au) и свинца (pb) возрастает после прохождения каждого этапа. Концентрация серебра (ag) после первичной очистки снижается.

# %% [markdown]
# ### Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной

# %%
# Распределению размеров гранул исходного сырья на обучающей выборке
gold_train.boxplot(column='rougher.input.feed_size', figsize=(15, 5), color='olive')
plt.title('Распределению размеров гранул исходного сырья на обучающей выборке')
plt.xlabel('Гранулы исходного сырья на обучающей выборке')
plt.ylabel('Распределение значений размера гранул вместе с выбросами')
plt.show()

# %%
# Распределение размеров гранул исходного сырья на тестовой выборке
gold_test.boxplot(column='rougher.input.feed_size', figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул исходного сырья на тестовой выборке')
plt.xlabel('Гранулы исходного сырья на тестовой выборке')
plt.ylabel('Распределение значений размера гранул вместе с выбросами')
plt.show()

# %%
# Распределение размеров гранул исходного сырья без выбросов на обучающей выборке
gold_train.boxplot(column='rougher.input.feed_size', showfliers=False, figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул исходного сырья без выбросов на обучающей выборке')
plt.xlabel('Гранулы исходного сырья на обучающей выборке')
plt.ylabel('Распределение значений размера гранул без выбросов')
plt.show()

# %%
# Распределение размеров гранул исходного сырья без выбросов на тестовой выборке
gold_test.boxplot(column='rougher.input.feed_size', showfliers=False, figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул исходного сырья без выбросов на тестовой выборке')
plt.xlabel('Гранулы исходного сырья на тестовой выборке')
plt.ylabel('Распределение значений размера гранул без выбросов')
plt.show()

# %%
# Распределение размера гранул исходного сырья на обучающей и тестовой выборках
gold_train['rougher.input.feed_size'].hist(figsize=(15, 5), bins=100, alpha=0.7, color='teal', edgecolor = 'gold')
gold_test['rougher.input.feed_size'].hist(figsize=(15, 5), bins=100, alpha=0.7, color='yellow', edgecolor = 'gold')
plt.grid(True)
plt.title('Распределение размера гранул исходного сырья на обучающей и тестовой выборках')
plt.legend(['Обучающая выборка', 'Тестовая выборка'])
plt.xlabel("Размер гранул исходного сырья")
plt.ylabel('Количество индексаций')
plt.show()

# %%
# Распределение размеров гранул при первичной очистке на обучающей выборке
gold_train.boxplot(column='primary_cleaner.input.feed_size', figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул при первичной очистке на обучающей выборке')
plt.xlabel('Гранулы при первичной очистке на обучающей выборке')
plt.ylabel('Распределение значений размера гранул вместе с выбросами')
plt.show()

# %%
# Распределение размеров гранул при первичной очистке на тестовой выборке
gold_test.boxplot(column='primary_cleaner.input.feed_size', figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул при первичной очистке на тестовой выборке')
plt.xlabel('Гранулы при первичной очистке на тестовой выборке')
plt.ylabel('Распределение значений размера гранул вместе с выбросами')
plt.show()

# %%
# Распределение размеров гранул при первичной очистке без выбросов на обучающей выборке
gold_train.boxplot(column='primary_cleaner.input.feed_size', showfliers=False, figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул при первичной очистке без выбросов на обучающей выборке')
plt.xlabel('Гранулы при первичной очистке на обучающей выборке')
plt.ylabel('Распределение значений размера гранул без выбросов')
plt.show()

# %%
# Распределение размеров гранул при первичной очистке без выбросов на тестовой выборке
gold_test.boxplot(column='primary_cleaner.input.feed_size', showfliers=False, figsize=(15, 5), color='olive')
plt.title('Распределение размеров гранул при первичной очистке без выбросов на тестовой выборке')
plt.xlabel('Гранулы при первичной очистке на тестовой выборке')
plt.ylabel('Распределение значений размера гранул без выбросов')
plt.show()

# %%
# Отдельно визуализируем распределение размера гранул при первичной очистке на обучающей и тестовой выборках
gold_train['primary_cleaner.input.feed_size'].hist(figsize=(15, 5), bins=100, alpha=0.7, color='teal', edgecolor = 'gold')
gold_test['primary_cleaner.input.feed_size'].hist(figsize=(15, 5), bins=100, alpha=0.7, color='yellow', edgecolor = 'gold')
plt.grid(True)
plt.title('Отдельно визуализируем распределение размера гранул при первичной очистке на обучающей и тестовой выборках')
plt.legend(['Обучающая выборка', 'Тестовая выборка'])
plt.xlabel("Размер гранул при первичной очистке")
plt.ylabel('Количество индексаций')
plt.show()

# %% [markdown]
# Распределения размеров гранул сырья на обучающей и тестовой выборках не сильно отличаются друг от друга.

# %%
for x,y in zip(('rougher.input.feed_size','primary_cleaner.input.feed_size'), ('исходного сырья','при первичной очистке')): 
    plt.figure(figsize=(15,5))
    sns.kdeplot(x=gold_train[x], label='обучающая выборка', color='teal')
    sns.kdeplot(x=gold_test[x], label='тестовая выборка', color='gold')
    plt.legend()
    plt.grid()
    plt.xlabel('Размер гранул')
    plt.ylabel('Плотность распределения размера гранул')
    plt.title('Распределение размера гранул на обучающей и тестовой выборках');

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %%
# В сырье
gold_train[rougher_input_feed].sum(1).head()
# Out:
# date
# 2016-01-15 00:00:00    51.680034
# 2016-01-15 01:00:00    50.659114
# 2016-01-15 02:00:00    50.609929
# 2016-01-15 03:00:00    51.061546
# 2016-01-15 04:00:00    47.859163
# dtype: float64

# %%
# В черновом концентрате
gold_train[rougher_output_concentrate].sum(1).head()
# Out:
# date
# 2016-01-15 00:00:00    66.424950
# 2016-01-15 01:00:00    67.012710
# 2016-01-15 02:00:00    66.103793
# 2016-01-15 03:00:00    65.752751
# 2016-01-15 04:00:00    65.908382
# dtype: float64

# %%
# В финальном концентрате
gold_train[final_output_concentrate].sum(1).head()
# Out:
# date
# 2016-01-15 00:00:00    63.644396
# 2016-01-15 01:00:00    63.957723
# 2016-01-15 02:00:00    64.311180
# 2016-01-15 03:00:00    63.573449
# 2016-01-15 04:00:00    64.004667
# dtype: float64

# %%
# Максимальные значения суммарной концентрации всех металлов в сырье на разных этапах
stages = [rougher_input_feed, rougher_output_concentrate, primary_cleaner_output_concentrate, final_output_concentrate]   
max_concentration = 0
plt.figure(figsize=(15, 5))
plt.grid(True)
plt.title('Максимальные значения суммарной концентрации всех металлов в сырье на разных этапах')
plt.xlabel('Суммарная концентрация')
plt.ylabel('Количество индексаций')
for stage in stages:
    concentration = gold_train[stage].sum(1)
    plt.hist(concentration, bins=100, alpha=0.7, edgecolor = 'gold')
    plt.legend(['в сырье', 'в черновом концентрате', 'в концентрате после первичной очистки', 'в финальном концентрате'])
    max_concentraition = max(max_concentration, int(concentration.max()))
    print(f'{stage}:', max_concentraition)
# Out:
# ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol']: 74
# ['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol']: 88
# ['primary_cleaner.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol']: 76
# ['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']: 80

# %%
gold_train.shape
# Out:
# (14149, 87)

# %%
columns_to_change = [column for column in gold_train.columns if 'concentrate' in column]
for col in columns_to_change:
    gold_train = gold_train[gold_train[col] > 0]
gold_train.shape
# Out:
# (13705, 87)

# %%
# Максимальные значения суммарной концентрации всех металлов в сырье
stages = [rougher_input_feed, rougher_output_concentrate,
    primary_cleaner_output_concentrate, final_output_concentrate]   
max_concentration = 0
plt.figure(figsize=(15, 5))
plt.grid(True)
plt.title('Максимальные значения суммарной концентрации всех металлов в сырье')
plt.xlabel('Концентрация')
plt.ylabel('Количество индексаций')
for stage in stages:
    concentration = gold_train[stage].sum(1)
    plt.hist(concentration, bins=100, alpha=0.7, edgecolor = 'gold')
    plt.legend(['в сырье', 'в черновом концентрате', 'после первичной очистки', 'в финальном концентрате'])
    max_concentraition = max(max_concentration, int(concentration.max()))
    print(f'{stage}:', max_concentraition)
# Out:
# ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol']: 74
# ['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol']: 88
# ['primary_cleaner.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol']: 76
# ['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']: 80

# %% [markdown]
# - Данные оптимизированны
# - Посмотрели как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки
# - Сравнили распределения размеров гранул сырья на обучающей и тестовой выборках
# - Распределения мало отличаются друг от друга, значит оценка модели будет правильной
# - Исследовали суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE

# %%
def smape_function(y_true, y_pred):
    error = np.abs(y_true - y_pred)
    scale = (np.abs(y_true) + np.abs(y_pred)) / 2
    return np.mean(error / scale) * 100

# %%
def final_smape_function(rougher, final):
    score_final = 0.25 * rougher + 0.75 * final
    return score_final

# %%
# Метрики оценки качества модели sMAPE с помощью функции make_scorer
smape_scorer = make_scorer(smape_function, greater_is_better=False)

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы

# %%
# Сохраним только те признаки из обучающей выборки, которые присутствуют одновременно в обучающей и в тестовой выборках
features_train = gold_train[features].reset_index(drop=True)

# %%
# Выделим из обучающего датасета таргет с целевыми признаками
target_train = gold_train[targets].reset_index(drop=True)

# %%
# Признаки в обучающей выборке
features_train.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# 1                     125.629232                         10.296251
# 2                     123.819808                         11.316280
# 3                     122.270188                         11.322140
# 4                     117.988169                         11.913613
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                             7.25                        0.988759
# 1                             7.25                        1.002663
# 2                             7.25                        0.991265
# 3                             7.25                        0.996739
# 4                             7.25                        1.009869
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1549.775757
# 1                             1576.166671
# ...

# %%
# Целевые признаки в обучающей выборке
display(target_train.head())
# Out:
#    rougher.output.recovery  final.output.recovery
# 0                87.107763              70.541216
# 1                86.843261              69.266198
# 2                86.842308              68.116445
# 3                87.226430              68.347543
# 4                86.688794              66.927016

# %%
# Модель дерева решений для таргета rougher 
model_dt_grid_rougher = DecisionTreeRegressor(random_state=42)
parameters = {'max_depth': range (1, 11, 1)} 
smape_score_dt_grid_rougher = GridSearchCV(model_dt_grid_rougher, parameters, scoring=smape_scorer, cv=3)
smape_score_dt_grid_rougher.fit(features_train, target_train.iloc[:, 0])
print('Лучшая модель:', smape_score_dt_grid_rougher.best_estimator_)
print('sMAPE лучшей модели:', f'{abs(smape_score_dt_grid_rougher.best_score_):.2f}%')
# Out:
# Лучшая модель: DecisionTreeRegressor(max_depth=4, random_state=42)
# sMAPE лучшей модели: 7.80%

# %%
# Модель дерева решений для таргета final
model_dt_grid_final = DecisionTreeRegressor(random_state=42)
parameters = {'max_depth': range (1, 11, 1)} 
smape_score_dt_grid_final = GridSearchCV(model_dt_grid_final, parameters, scoring=smape_scorer, cv=3)
smape_score_dt_grid_final.fit(features_train, target_train.iloc[:, 1])
print('Лучшая модель:', smape_score_dt_grid_final.best_estimator_)
print('sMAPE лучшей модели:', f'{abs(smape_score_dt_grid_final.best_score_):.2f}%')
# Out:
# Лучшая модель: DecisionTreeRegressor(max_depth=2, random_state=42)
# sMAPE лучшей модели: 9.85%

# %%
# Итоговое sMAPE модели случайного леса
final_smape_dt_grid = final_smape_function(smape_score_dt_grid_rougher.best_score_, 
                                           smape_score_dt_grid_final.best_score_)
print('Итоговое sMAPE модели случайного леса:', f'{abs(final_smape_dt_grid):.2f}%')
# Out:
# Итоговое sMAPE модели случайного леса: 9.34%

# %%
# Модель случайного леса для таргета rougher 
model_rf_grid_rougher = RandomForestRegressor(random_state=42)
parameters = {'n_estimators': range (5, 55, 5), 'max_depth': range (1, 11, 1)}   
smape_score_rf_grid_rougher = GridSearchCV(model_rf_grid_rougher, parameters, scoring=smape_scorer, cv=3)
smape_score_rf_grid_rougher.fit(features_train, target_train.iloc[:, 0])
print('Лучшая модель:', smape_score_rf_grid_rougher.best_estimator_)
print('sMAPE лучшей модели:', f'{abs(smape_score_rf_grid_rougher.best_score_):.2f}%')
# Out:
# Лучшая модель: RandomForestRegressor(max_depth=2, n_estimators=10, random_state=42)
# sMAPE лучшей модели: 7.84%

# %%
# Модель случайного леса для таргета final 
model_rf_grid_final = RandomForestRegressor(random_state=42)
parameters = {'n_estimators': range (5, 55, 5), 'max_depth': range (1, 11, 1)} 
smape_score_rf_grid_final = GridSearchCV(model_rf_grid_final, parameters, scoring=smape_scorer, cv=3)
smape_score_rf_grid_final.fit(features_train, target_train.iloc[:, 1])
print('Лучшая модель:', smape_score_rf_grid_final.best_estimator_)
print('sMAPE лучшей модели:', f'{abs(smape_score_rf_grid_final.best_score_):.2f}%')
# Out:
# Лучшая модель: RandomForestRegressor(max_depth=1, n_estimators=5, random_state=42)
# sMAPE лучшей модели: 10.00%

# %%
# Итоговое sMAPE модели случайного леса
final_smape_rf_grid = final_smape_function(smape_score_rf_grid_rougher.best_score_, smape_score_rf_grid_final.best_score_)
print('Итоговое sMAPE модели случайного леса:', f'{abs(final_smape_rf_grid):.2f}%')
# Out:
# Итоговое sMAPE модели случайного леса: 9.46%

# %%
# Модель линейной регрессии для таргета rougher
model_lr_cross_rougher = LinearRegression()
smape_scores_lr_cross_rougher = cross_val_score(model_lr_cross_rougher, 
                                                features_train, target_train.iloc[:, 0], scoring = smape_scorer, cv = 3)
final_smape_scores_lr_cross_rougher = abs(smape_scores_lr_cross_rougher.mean())
print('sMAPE лучшей модели:', f'{final_smape_scores_lr_cross_rougher:.2f}%')
# Out:
# sMAPE лучшей модели: 10.55%

# %%
# Модель линейной регрессии для таргета final
model_lr_cross_final = LinearRegression()
smape_scores_lr_cross_final = cross_val_score(model_lr_cross_final, features_train, 
                                              target_train.iloc[:, 1], scoring = smape_scorer, cv = 3)
final_smape_scores_lr_cross_final = abs(smape_scores_lr_cross_final.mean())
print('sMAPE лучшей модели:', f'{final_smape_scores_lr_cross_final:.2f}%')
# Out:
# sMAPE лучшей модели: 13.66%

# %%
# Итоговое sMAPE модели линейной регрессии
final_smape_lr_cross = final_smape_function(final_smape_scores_lr_cross_rougher, final_smape_scores_lr_cross_final)
print('Итоговое sMAPE модели линейной регрессии:', f'{abs(final_smape_lr_cross):.2f}%')
# Out:
# Итоговое sMAPE модели линейной регрессии: 12.89%

# %%
# Проверим лучшую модель на тестовой выборке для таргета rougher и получим предсказания
predictions_test_rougher = pd.Series(smape_score_rf_grid_rougher.predict(features_test))
smape_test_rougher = smape_function(target_test.iloc[:, 0], predictions_test_rougher) 
print('sMAPE лучшей модели:', f'{abs(smape_test_rougher):.2f}%')
# Out:
# sMAPE лучшей модели: 8.41%

# %%
# Проверим лучшую модель на тестовой выборке для таргета final и получим предсказания
predictions_test_final = pd.Series(smape_score_rf_grid_final.predict(features_test))
smape_test_final = smape_function(target_test.iloc[:, 1], predictions_test_final) 
print('sMAPE лучшей модели:', f'{abs(smape_test_final):.2f}%')
# Out:
# sMAPE лучшей модели: 9.59%

# %%
# Итоговая метрика оценки качества модели случайного леса sMAPE
final_smape = final_smape_function(smape_test_rougher, smape_test_final)
print('Итоговая метрика оценки качества модели случайного леса sMAPE:', f'{abs(final_smape):.2f}%')
# Out:
# Итоговая метрика оценки качества модели случайного леса sMAPE: 9.29%

# %%
# Проверим модели на адекватность для таргета rougher
model_dummy_rougher = DummyRegressor(strategy='median')
model_dummy_rougher.fit(features_train, target_train.iloc[:, 0]) 
predictions_dummy_rougher = pd.Series(model_dummy_rougher.predict(features_test))
smape_dummy_rougher = smape_function(target_test.iloc[:, 0], predictions_dummy_rougher)
print('Наивный прогноз sMAPE:', f'{abs(smape_dummy_rougher):.2f}%')
# Out:
# Наивный прогноз sMAPE: 8.52%

# %%
# Проверим модели на адекватность для таргета final
model_dummy_final = DummyRegressor(strategy='median')
model_dummy_final.fit(features_train, target_train.iloc[:, 1]) 
predictions_dummy_final = pd.Series(model_dummy_final.predict(features_test))
smape_dummy_final = smape_function(target_test.iloc[:, 1], predictions_dummy_final)
print('Наивный прогноз sMAPE:', f'{abs(smape_dummy_final):.2f}%')
# Out:
# Наивный прогноз sMAPE: 9.74%

# %% [markdown]
# - Написали функцию для вычисления итоговой sMAPE
# - Обучили разные модели и оценили их качество
# - Выбрали лучшую модель и проверили её на тестовой выборке

# %% [markdown]
# Подготовили прототип модели машинного обучения для «Цифры».
# Компания разрабатывает решения для эффективной работы промышленных предприятий.
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# 1. Подготовили и изучили данные
# 2. Эффективность обогащения рассчитана правильно
# 3. В тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков
# 4. Провели предобработку данных
# 5. Данные оптимизированны
# 6. Посмотрели как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки
# 7. Сравнили распределения размеров гранул сырья на обучающей и тестовой выборках
# 8. Распределения мало отличаются друг от друга, значит оценка модели будет правильной
# 9. Исследовали суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах
# 10. Написали функцию для вычисления итоговой sMAPE
# 11. Обучили разные модели и оценили их качество
# 12. Выбрали лучшую модель и проверили её на тестовой выборке
#
# - Лучшая модель случайного леса для таргета "rougher": RandomForestRegressor(max_depth=2, n_estimators=12, random_state=42) sMAPE лучшей модели случайного леса для таргета "rougher": 7.84%
# - Лучшая модель случайного леса для таргета "final": RandomForestRegressor(max_depth=1, n_estimators=3, random_state=42) sMAPE лучшей модели случайного лесадля таргета "final": 10.00%
# - Проверили лучшую модель на тестовой выборке для таргета rougher sMAPE: 8.41%
# - Проверили лучшую модель на тестовой выборке для таргета final sMAPE: 9.56%
# - Итоговая метрика оценки качества модели случайного леса sMAPE: 9.29%
# - Проверили модели на адекватность для таргета rougher, наивный прогноз sMAPE: 8.52%
# - Проверили модели на адекватность для таргета final, наивный прогноз sMAPE: 9.74%
